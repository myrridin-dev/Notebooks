# %% [markdown]
# ### Embeddings using SentenceTransformer

# %%
from sentence_transformers import SentenceTransformer

st_model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
state_of_the_union_path = '/Users/shivramamurthi/models/state_of_the_union.txt'

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader(state_of_the_union_path)
unchunked_docs = loader.load()

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=512, chunk_overlap=0)
chunked_docs = text_splitter.split_documents(unchunked_docs)
sentences_txt = [ doc.page_content for doc in chunked_docs ]
print(len(sentences_txt))
sentences_txt[0]
# Out:
# 88
# 'Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny.'

# %% [markdown]
# #### 0.6 s to encode 88 sentences

# %%
st_embeddings = st_model.encode(sentences_txt)
print(st_embeddings.shape)
print(sentences_txt[0], st_embeddings[0])
# Out:
# (88, 768)
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny. [-5.95337510e-01  3.82333487e-01  3.65825891e-01  2.53147274e-01
#   2.29489878e-01 -9.63458002e-01  6.49914980e-01 -5.62279046e-01
#   3.65178548e-02 -7.56203771e-01  4.52899843e-01  9.13165212e-01
#   1.33935973e-01  3.49942416e-01 -8.26504230e-01  5.22772014e-01
#   5.52295260e-02 -1.10473216e-01  6.39623553e-02 -2.17773944e-01
#  -1.99016690e-01  1.47524565e-01  4.18507278e-01  4.94993001e-01
#   9.14852321e-01  6.15755975e-01 -3.44736949e-02 -5.21782458e-01
#  -6.09696567e-01  7.11840391e-01 -1.42915547e-01 -1.34216622e-01
#  -7.66322136e-01 -4.29587901e-01  2.57895231e-01  8.08755815e-01
#   6.19327724e-01  4.55921680e-01  3.26944441e-01  2.20539078e-01
#   3.96779358e-01 -3.83025885e-01  3.73800516e-01 -3.73216361e-01
#  -1.18572152e+00 -3.70984495e-01  3.99868488e-01  8.80045235e-01
#   9.83660638e-01 -1.45575917e+00  5.44659495e-01  7.81916380e-02
#   8.22196960e-01  7.34973252e-02 -2.75290310e-01 -4.53942895e-01
#   2.08912835e-01 -9.74649131e-01 -1.23652029e+00 -8.94139588e-01
#  -4.91834283e-01  1.89136490e-01  2.42975876e-01  5.74644394e-02
#  -4.97960448e-02  7.60397434e-01  1.09730974e-01 -2.75348932e-01
#  -6.38630927e-01 -1.63819809e-02 -1.31446987e-01 -1.05227363e+00
#  -5.13727546e-01 -2.70595431e-01  2.50044525e-01 -3.33949268e-01
#  -3.35818648e-01 -2.40065306e-02  1.01570761e+00  5.29504478e-01
#   3.09576452e-01 -4.70076352e-01  5.58031499e-01  1.34894833e-01
#   1.12154573e-01  1.56490833e-01  4.70129371e-01 -2.26398587e-01
#   8.34415108e-02 -1.83623716e-01  1.61316171e-01 -5.38108110e-01
#  -4.79278862e-01  8.73152018e-02  5.93197167e-01  2.02387214e-01
#  -1.46132421e+00  8.85946870e-01  2.21298099e-01 -3.03742945e-01
#   9.02054906e-01  6.15959346e-01 -4.08973321e-02 -2.95699477e-01
#   2.52668172e-01  3.87734383e-01 -1.30683124e-01  7.73631334e-01
#   3.22444171e-01 -3.68653446e-01 -8.14909279e-01  7.64995515e-01
#   5.00484817e-02 -1.20814964e-01 -9.54613924e-01 -4.14534844e-02
#  -4.15586561e-01  1.32381707e-01 -1.53948963e-01 -6.97728455e-01
#   1.90654710e-01 -1.89427823e-01  3.52299511e-01  8.98935944e-02
#  -1.49294183e-01 -3.64160031e-01  2.94527560e-02 -5.27922392e-01
#   4.18828577e-01 -5.32463908e-01  5.91186523e-01  4.07143682e-01
#  -1.15326054e-01 -3.32356155e-01 -6.47661924e-01 -1.57150662e+00
#   6.92461312e-01 -4.17655230e-01 -1.45639688e-01 -2.86436737e-01
#   5.51669657e-01  4.28597242e-01 -7.72475719e-01  2.64600009e-01
#   1.68820888e-01  7.06110358e-01 -2.11878955e-01 -7.28814721e-01
#   2.14294121e-01  1.56613812e-01 -2.80445129e-01 -3.12197600e-02
#   3.15642923e-01 -8.70454162e-02 -5.29436290e-01 -3.75389874e-01
#  -6.39625847e-01 -1.12913990e+00  6.86684728e-01 -5.69889009e-01
#  -2.56363928e-01 -8.43494982e-02  2.57827103e-01  9.43497866e-02]

# %% [markdown]
# ### Embeddings using local llama2

# %%
from langchain_community.embeddings import LlamaCppEmbeddings

llama_model_path='/Users/shivramamurthi/src/llama.cpp/models/llama-2-7b/ggml-model-q4_0.bin'

embeddings = LlamaCppEmbeddings(
    model_path=llama_model_path
)
# Out:
# llama_model_loader: loaded meta data with 16 key-value pairs and 291 tensors from /Users/shivramamurthi/src/llama.cpp/models/llama-2-7b/ggml-model-q4_0.bin (version GGUF V3 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q4_0     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:               output_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    2:                    output.weight q6_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    4:              blk.0.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    5:              blk.0.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    6:         blk.0.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    7:            blk.0.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor    8:            blk.0.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor    9:              blk.0.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   10:           blk.0.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   11:            blk.0.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   12:              blk.1.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   13:              blk.1.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   14:              blk.1.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   15:         blk.1.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   16:            blk.1.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   17:            blk.1.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   18:              blk.1.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   19:           blk.1.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   20:            blk.1.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   21:              blk.2.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   22:              blk.2.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   23:              blk.2.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   24:         blk.2.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   25:            blk.2.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   26:            blk.2.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   27:              blk.2.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   28:           blk.2.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   29:            blk.2.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   30:              blk.3.attn_q.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   31:              blk.3.attn_k.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   32:              blk.3.attn_v.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   33:         blk.3.attn_output.weight q4_0     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   34:            blk.3.ffn_gate.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   35:            blk.3.ffn_down.weight q4_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   36:              blk.3.ffn_up.weight q4_0     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   37:           blk.3.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_0:  225 tensors
# llama_model_loader: - type q6_K:    1 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 4096
# llm_load_print_meta: n_head           = 32
# llm_load_print_meta: n_head_kv        = 32
# llm_load_print_meta: n_layer          = 32
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 11008
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 7B
# llm_load_print_meta: model ftype      = Q4_0
# llm_load_print_meta: model params     = 6.74 B
# llm_load_print_meta: model size       = 3.56 GiB (4.54 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.11 MiB
# llm_load_tensors: mem required  = 3647.98 MiB
# ..................................................................................................
# llama_new_context_with_model: n_ctx      = 512
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: KV self size  =  256.00 MiB, K (f16):  128.00 MiB, V (f16):  128.00 MiB
# llama_build_graph: non-view tensors processed: 676/676
# llama_new_context_with_model: compute buffer total size = 4.29 MiB
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | SSSE3 = 0 | VSX = 0 |

# %% [markdown]
# #### 28s to embed 88 sentences

# %%
llama2_embeddings = embeddings.embed_documents(sentences_txt)
len(llama2_embeddings)
# Out:
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5038.28 ms /   124 tokens (   40.63 ms per token,    24.61 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5054.32 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4440.11 ms /   112 tokens (   39.64 ms per token,    25.22 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4453.58 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3889.57 ms /    98 tokens (   39.69 ms per token,    25.20 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3902.48 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5061.36 ms /   128 tokens (   39.54 ms per token,    25.29 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5076.83 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4995.81 ms /   127 tokens (   39.34 ms per token,    25.42 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5011.40 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    2836.57 ms /    72 tokens (   39.40 ms per token,    25.38 tokens per second)
# llama_print_timings:        eval time =      42.09 ms /     1 runs   (   42.09 ms per token,    23.76 tokens per second)
# llama_print_timings:       total time =    2887.73 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4493.97 ms /   116 tokens (   38.74 ms per token,    25.81 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4508.21 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5010.66 ms /   128 tokens (   39.15 ms per token,    25.55 tokens per second)
# llama_print_timings:        eval time =      43.01 ms /     1 runs   (   43.01 ms per token,    23.25 tokens per second)
# llama_print_timings:       total time =    5070.28 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3957.37 ms /   101 tokens (   39.18 ms per token,    25.52 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3969.59 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4594.63 ms /   117 tokens (   39.27 ms per token,    25.46 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4609.24 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4245.89 ms /   107 tokens (   39.68 ms per token,    25.20 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4259.51 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4493.57 ms /   114 tokens (   39.42 ms per token,    25.37 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4507.68 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    2929.76 ms /    75 tokens (   39.06 ms per token,    25.60 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    2940.05 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3431.36 ms /    88 tokens (   38.99 ms per token,    25.65 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3441.81 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4944.82 ms /   126 tokens (   39.24 ms per token,    25.48 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4960.24 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3256.06 ms /    83 tokens (   39.23 ms per token,    25.49 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3266.43 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4888.86 ms /   124 tokens (   39.43 ms per token,    25.36 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4904.30 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4010.19 ms /   103 tokens (   38.93 ms per token,    25.68 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4022.32 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4356.34 ms /   112 tokens (   38.90 ms per token,    25.71 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4370.00 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4821.73 ms /   123 tokens (   39.20 ms per token,    25.51 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4837.60 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4237.17 ms /   109 tokens (   38.87 ms per token,    25.72 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4250.81 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3840.09 ms /    98 tokens (   39.18 ms per token,    25.52 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3852.55 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5177.34 ms /   133 tokens (   38.93 ms per token,    25.69 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5193.25 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3411.74 ms /    88 tokens (   38.77 ms per token,    25.79 tokens per second)
# llama_print_timings:        eval time =      43.00 ms /     1 runs   (   43.00 ms per token,    23.25 tokens per second)
# llama_print_timings:       total time =    3466.00 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4801.13 ms /   124 tokens (   38.72 ms per token,    25.83 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4816.27 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5139.75 ms /   132 tokens (   38.94 ms per token,    25.68 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5156.39 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4119.04 ms /   106 tokens (   38.86 ms per token,    25.73 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4131.80 ms
#
# llama_print_timings:        load time =     386.48 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4664.83 ms /   119 tokens (   39.20 ms per token,    25.51 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4678.93 ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 llama2_embeddings = embeddings.embed_documents(sentences_txt)
#       2 len(llama2_embeddings)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/langchain_community/embeddings/llamacpp.py:113, in LlamaCppEmbeddings.embed_documents(self, texts)
#     104 def embed_documents(self, texts: List[str]) -> List[List[float]]:
#     105     """Embed a list of documents using the Llama model.
#     106
#     107     Args:
#    (...)
#     111         List of embeddings, one for each text.
#     112     """
# --> 113     embeddings = [self.client.embed(text) for text in texts]
#     114     return [list(map(float, e)) for e in embeddings]
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/langchain_community/embeddings/llamacpp.py:113, in <listcomp>(.0)
#     104 def embed_documents(self, texts: List[str]) -> List[List[float]]:
#     105     """Embed a list of documents using the Llama model.
#     106
#     107     Args:
#    (...)
#     111         List of embeddings, one for each text.
#     112     """
# --> 113     embeddings = [self.client.embed(text) for text in texts]
#     114     return [list(map(float, e)) for e in embeddings]
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/llama_cpp/llama.py:1343, in Llama.embed(self, input)
#    1334 def embed(self, input: str) -> List[float]:
#    1335     """Embed a string.
#    1336
#    1337     Args:
#    (...)
#    1341         A list of embeddings
#    1342     """
# -> 1343     return list(map(float, self.create_embedding(input)["data"][0]["embedding"]))
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/llama_cpp/llama.py:1307, in Llama.create_embedding(self, input, model)
#    1305 tokens = self.tokenize(input.encode("utf-8"), special=True)
#    1306 self.reset()
# -> 1307 self.eval(tokens)
#    1308 n_tokens = len(tokens)
#    1309 total_tokens += n_tokens
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/llama_cpp/llama.py:1069, in Llama.eval(self, tokens)
#    1065 n_tokens = len(batch)
#    1066 self._batch.set_batch(
#    1067     batch=batch, n_past=n_past, logits_all=self.context_params.logits_all
#    1068 )
# -> 1069 self._ctx.decode(self._batch)
#    1070 # Save tokens
#    1071 self.input_ids[n_past : n_past + n_tokens] = batch
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/llama_cpp/llama.py:469, in _LlamaContext.decode(self, batch)
#     467 assert self.ctx is not None
#     468 assert batch.batch is not None
# --> 469 return_code = llama_cpp.llama_decode(
#     470     ctx=self.ctx,
#     471     batch=batch.batch,
#     472 )
#     473 if return_code != 0:
#     474     raise RuntimeError(f"llama_decode returned {return_code}")
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/llama_cpp/llama_cpp.py:1482, in llama_decode(ctx, batch)
#    1477 def llama_decode(ctx: llama_context_p, batch: llama_batch) -> int:
#    1478     """Positive return values does not mean a fatal error, but rather a warning.
#    1479     0 - success
#    1480     1 - could not find a KV slot for the batch (try reducing the size of the batch or increase the context)
#    1481     < 0 - error"""
# -> 1482     return _lib.llama_decode(ctx, batch)
#
# KeyboardInterrupt:

# %%
print(sentences_txt[0], llama2_embeddings[0])
# Out:
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny. [0.0023242115053150585, 0.0002475537968620424, 0.011010420782432263, 0.000868643902896479, -0.007935231340261754, -0.006551973387163167, 0.026386503159583324, -0.01882366731567656, -0.012369685174550681, -0.007982018012675948, -0.011451162901610686, -0.010787027305656689, 0.008323412902447988, 0.00723071928731067, -0.008138714636107186, 0.010411274870956463, -0.01841826593737851, 0.005382793545801603, -0.0037687783300482287, -0.01778974388369275, 0.04035385768573307, -0.013299394773183962, -0.016360811448453572, 0.00584908888457362, -0.01441172329907272, -0.005193582947002252, -0.004643919318939512, 0.0029215593655619074, 0.03852265923656316, 0.02041378093290857, -0.015137120705335905, 0.004068756167483954, 0.004965966294895313, -0.0006348119155493964, -0.0053388848663096095, 0.012425988418456919, -0.010327076759344508, -0.004284813323678416, 0.028427746333454754, -0.011933189375617752, 0.009609578249375195, -0.032510514123353415, -0.009654217073758237, 0.022010114668662973, 0.008353316131502374, 0.0029350747610176952, 0.00031185750466031925, 0.006481953541347648, 0.0015191679748513397, 0.012770382271902341, -0.007861728647768136, 0.025849546089377284, 0.01122434150875321, -0.027805233316674536, 0.01855188430403366, 0.006590609346617768, 0.009479343977764529, -0.017453290895985487, 0.010048174372115595, -0.01579531885931873, 0.00650859611489957, 0.004665946796614155, -0.006433081357871024, 0.007042394984423024, -0.011559995842623605, -0.023885408191033332, -0.00148844078685397, -0.013168230384624176, -0.003953724709868493, 0.009815462444312919, -0.001732606361161843, 0.0016164645648659097, 0.00273350076628846, 0.01128420104586505, -0.043839365720358, 0.007200835191385298, -0.0018926599229383205, -0.013433711807646945, -0.0004985156823295478, -0.013318898220823149, -0.017480850008136907, -0.028507271024005826, -0.00440221512909952, -0.018334381362203285, 0.008038587268795238, 0.008263116389357398, 0.0023153928301337104, -0.010891062151671285, -0.0029008097957460275, 0.00938165701019832, -0.023573656690079724, -0.005446279119460285, -0.009047358659697016, 0.01650716136947268, 0.01758425284369636, 0.0027911365400508053, 0.019555073758845284, -0.005037941423056431, 0.010567202466040917, 0.0002388195234675505, 0.003580620361943455, -0.001423013972097594, 0.01816098954071382, 0.003872639743506286, 0.012326951639498719, 0.024526548234704394, 0.018696578900794278, -0.004497137359523332, -0.013709512776382602, 0.005249703500386301, 0.006370663536250817, 0.009885770521459055, 0.06857262581212936, 0.009869760412859039, -0.005105251462325752, 0.0025907747216242084, -0.002289614487675357, -0.008129900435609235, 0.014090998977809664, 0.00022345801251113723, 0.016017771726784112, 0.015741851021692697, -0.0047478325770052175, -0.015536214323036722, -0.004447416837794174, -0.018355438913676508, 0.004070512712166902, -0.035493976259046454, 0.01220569944616315, -0.02152283460774753, -0.017614552313680632, -0.012502156787860461, 0.0073574478759279634, -0.0025629045418268954, -0.011024197869717135, 0.028592217179242423, -0.018322611401871663, -0.01826870658826688, 0.009217505872824484, 0.0028980561681624124, 0.003801298168794586, 0.005278873498561086, -0.01587231921123549, -0.017524467370309733, -0.0016414619979215584, 0.0017129092677411128, -0.0013666389789575568, 0.010383363956110284, 0.007356817717065951, 0.05684753822282173, 3.496518812841988e-05, -0.012098435421729307, 0.015609025136897317, -0.007862252031426301, 0.010181195291387366, 0.028747042459216637, 0.012870866996688437, 0.01492855231755695, -0.025523021344034703, 0.014860369252126693, 0.012449904829723326, 0.013229541570750172, 0.015650409477755, 0.0029423181933434382, 0.001677042211513451, -0.006438490478602348, -0.007093550182229312, -0.0013752260506981896, 0.016879229133843605, -0.0036164551695907644, -0.003850278979068188, 0.020320510014958132, -0.0018394750704623668, 0.003279252903863437, -0.00543204777 ...

# %% [markdown]
# #### Computing similarities

# %%
from sklearn.metrics.pairwise import cosine_similarity
from langchain_community.embeddings import SentenceTransformerEmbeddings

# %%
embeddings = SentenceTransformerEmbeddings(model_name='all-mpnet-base-v2')

# %% [markdown]
# ##### Without any context `bank` is not similar to `river`

# %%
e1 = embeddings.embed_query('bank')
e2 = embeddings.embed_query('river')

cosine_similarity([e1], [e2])
# Out:
# array([[0.35636227]])

# %% [markdown]
# ##### With some context `bank of a river` similar to `river`

# %%
e1 = embeddings.embed_query('bank of a river')
e2 = embeddings.embed_query('river')

cosine_similarity([e1], [e2])
# Out:
# array([[0.72273722]])

# %% [markdown]
# ##### With more context financial institutions are more similar

# %%
e1 = embeddings.embed_query('bank of england')
e2 = embeddings.embed_query('river')
e3 = embeddings.embed_query('bank of scotland')

cosine_similarity([e1], [e2, e3])
# Out:
# array([[0.23622898, 0.82905475]])

# %% [markdown]
# ### [Word2Vec embeddings](https://www.geeksforgeeks.org/python-word-embedding-using-word2vec/)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/shivramamurthi/.local/lib/python3.11/site-packages (from nltk) (4.66.2)

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy>=1.18.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages (from gensim) (1.10.1)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-7.0.4-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Downloading gensim-4.3.2-cp311-cp311-macosx_11_0_arm64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 15.1 MB/s eta 0:00:0000:0100:01
# Downloading smart_open-7.0.4-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: smart-open, gensim
# Successfully installed gensim-4.3.2 smart-open-7.0.4

# %%
# Python program to generate word vectors using Word2Vec
import gensim

# importing all necessary modules
from gensim.models import Word2Vec
import gensim
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings

warnings.filterwarnings(action='ignore')


# Reads ‘alice.txt’ file
sample = open('/Users/shivramamurthi/models/state_of_the_union.txt')
s = sample.read()

# Replaces escape character with space
f = s.replace("\n", " ")

data = []

# iterate through each sentence in the file
for i in sent_tokenize(f):
	temp = []

	# tokenize the sentence into words
	for j in word_tokenize(i):
		temp.append(j.lower())

	data.append(temp)

print(data)

# Create CBOW model
model1 = gensim.models.Word2Vec(data, min_count=1,
								vector_size=100, window=5)

# Print results
print(model1.wv.similarity('ukraine', 'america'))
print(model1.wv.similarity('ukraine', 'union'))

# Create Skip Gram model
model2 = gensim.models.Word2Vec(data, min_count=1, vector_size=100,
								window=5, sg=1)

# Print results
print(model2.wv.similarity('ukraine', 'america'))
print(model2.wv.similarity('ukraine', 'union'))

sample.close()
# Out:
# [['madam', 'speaker', ',', 'madam', 'vice', 'president', ',', 'our', 'first', 'lady', 'and', 'second', 'gentleman', '.'], ['members', 'of', 'congress', 'and', 'the', 'cabinet', '.'], ['justices', 'of', 'the', 'supreme', 'court', '.'], ['my', 'fellow', 'americans', '.'], ['last', 'year', 'covid-19', 'kept', 'us', 'apart', '.'], ['this', 'year', 'we', 'are', 'finally', 'together', 'again', '.'], ['tonight', ',', 'we', 'meet', 'as', 'democrats', 'republicans', 'and', 'independents', '.'], ['but', 'most', 'importantly', 'as', 'americans', '.'], ['with', 'a', 'duty', 'to', 'one', 'another', 'to', 'the', 'american', 'people', 'to', 'the', 'constitution', '.'], ['and', 'with', 'an', 'unwavering', 'resolve', 'that', 'freedom', 'will', 'always', 'triumph', 'over', 'tyranny', '.'], ['six', 'days', 'ago', ',', 'russia', '’', 's', 'vladimir', 'putin', 'sought', 'to', 'shake', 'the', 'foundations', 'of', 'the', 'free', 'world', 'thinking', 'he', 'could', 'make', 'it', 'bend', 'to', 'his', 'menacing', 'ways', '.'], ['but', 'he', 'badly', 'miscalculated', '.'], ['he', 'thought', 'he', 'could', 'roll', 'into', 'ukraine', 'and', 'the', 'world', 'would', 'roll', 'over', '.'], ['instead', 'he', 'met